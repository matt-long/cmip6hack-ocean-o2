# %% [markdown]
# # Upper ocean oxygen versus temperature
#
# Compute global mean temperature and oxygen concentration for the upper 1000 m.
#
# Plot O2 anomalies versus temperature anomalies.

# %%
# %matplotlib inline

from itertools import product

import numpy as np

import pandas as pd
import xarray as xr
import intake

# util.py is in the local directory
# it contains code that is common across project notebooks
# or routines that are too extensive and might otherwise clutter
# the notebook design
import util

# %% [markdown]
# ## Spin-up a dask cluster
# Syntax is different if on an NCAR machine versus the cloud.

# %%
if util.is_ncar_host():
    from ncar_jobqueue import NCARCluster
    cluster = NCARCluster(project='UCGD0006')
    cluster.adapt(minimum_jobs=1, maximum_jobs=10)
else:
    from dask_kubernetes import KubeCluster
    cluster = KubeCluster()
    cluster.adapt(minimum=1, maximum=10)
cluster
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-2-adfe82390181> in <module>
#       1 if util.is_ncar_host():
# ----> 2     from ncar_jobqueue import NCARCluster
#       3     cluster = NCARCluster(project='UCGD0006')
#       4     cluster.adapt(minimum_jobs=1, maximum_jobs=10)
#       5 else:
#
# /ncar/usr/jupyterhub/envs/cmip6-201910/lib/python3.7/site-packages/ncar_jobqueue/__init__.py in <module>
#       3 from pkg_resources import DistributionNotFound, get_distribution
#       4
# ----> 5 from . import config
#       6 from .cluster import NCARCluster
#       7
#
# /ncar/usr/jupyterhub/envs/cmip6-201910/lib/python3.7/site-packages/ncar_jobqueue/config.py in <module>
#     100 destination = os.path.join(os.path.expanduser('~'), '.dask')
#     101
# --> 102 with open(config_path, 'w') as outfile:
#     103     data = _generate_config(config_data_file_path, template_file_path)
#     104     data = yaml.safe_load(data)
#
# PermissionError: [Errno 13] Permission denied: '/ncar/usr/jupyterhub/envs/cmip6-201910/lib/python3.7/site-packages/ncar_jobqueue/jobqueue.yaml'

# %%
from dask.distributed import Client
client = Client(cluster) # Connect this local process to remote workers
client

# %% [markdown]
# ## Open `intake-esm` collection

# %%
if util.is_ncar_host():
    col = intake.open_esm_datastore("../catalogs/glade-cmip6.json")
else:
    col = intake.open_esm_datastore("../catalogs/pangeo-cmip6.json")
col
# Out:
# glade-cmip6-ESM Collection with 698724 entries:
# 	> 13 activity_id(s)
#
# 	> 24 institution_id(s)
#
# 	> 47 source_id(s)
#
# 	> 68 experiment_id(s)
#
# 	> 162 member_id(s)
#
# 	> 35 table_id(s)
#
# 	> 1027 variable_id(s)
#
# 	> 12 grid_label(s)
#
# 	> 59 dcpp_init_year(s)
#
# 	> 248 version(s)
#
# 	> 6813 time_range(s)
#
# 	> 698724 path(s)

# %% [markdown]
# `intake-esm` is build on top of [pandas](https://pandas.pydata.org/pandas-docs/stable). It is possible to view the `pandas.DataFrame` as follows.

# %%
col.df.head()
# Out:
#   activity_id institution_id source_id experiment_id member_id table_id  \
# 0  AerChemMIP            BCC  BCC-ESM1        ssp370  r2i1p1f1      day
# 1  AerChemMIP            BCC  BCC-ESM1        ssp370  r2i1p1f1     Amon
# 2  AerChemMIP            BCC  BCC-ESM1        ssp370  r2i1p1f1     Amon
# 3  AerChemMIP            BCC  BCC-ESM1        ssp370  r2i1p1f1     Amon
# 4  AerChemMIP            BCC  BCC-ESM1        ssp370  r2i1p1f1     Amon
#
#   variable_id grid_label  dcpp_init_year    version         time_range  \
# 0          pr         gn             NaN  v20190702  20150101-20551231
# 1        hfls         gn             NaN  v20190624      201501-205512
# 2        prsn         gn             NaN  v20190624      201501-205512
# 3          va         gn             NaN  v20190624      201501-205512
# 4         tas         gn             NaN  v20190624      201501-205512
#
#                                                 path
# 0  /glade/collections/cmip/CMIP6/AerChemMIP/BCC/B...
# 1  /glade/collections/cmip/CMIP6/AerChemMIP/BCC/B...
# 2  /glade/collections/cmip/CMIP6/AerChemMIP/BCC/B...
# 3  /glade/collections/cmip/CMIP6/AerChemMIP/BCC/B...
# 4  /glade/collections/cmip/CMIP6/AerChemMIP/BCC/B...

# %% [markdown]
# ### Finding unique entries
# Query the data to see what models ("source_id"), experiments ("experiment_id") and temporal frequencies ("table_id") are available.

# %%
import pprint 
uni_dict = col.unique(['source_id', 'experiment_id', 'table_id'])
pprint.pprint(uni_dict, compact=True)
# Out:
# {'experiment_id': {'count': 68,
#                    'values': ['ssp370', 'histSST-piNTCF', 'histSST',
#                               'histSST-1950HC', 'hist-1950HC', 'hist-piNTCF',
#                               'piClim-NTCF', 'ssp370SST-lowNTCF',
#                               'ssp370-lowNTCF', 'ssp370SST', '1pctCO2-bgc',
#                               'hist-bgc', 'esm-ssp585', 'amip-future4K',
#                               'amip-m4K', 'a4SST', 'aqua-p4K', 'piSST',
#                               'amip-4xCO2', 'a4SSTice', 'amip-p4K',
#                               'aqua-control', 'aqua-4xCO2', 'abrupt-4xCO2',
#                               'historical', 'piControl', 'amip', '1pctCO2',
#                               'esm-hist', 'esm-piControl', 'ssp245', 'ssp585',
#                               'ssp126', 'hist-GHG', 'hist-aer',
#                               'dcppA-hindcast', 'dcppC-hindcast-noPinatubo',
#                               'dcppC-hindcast-noElChichon', 'dcppA-assim',
#                               'dcppC-hindcast-noAgung', 'hist-1950',
#                               'highresSST-present', 'control-1950',
#                               'land-hist-princeton', 'land-hist-cruNcep',
#                               'land-hist', 'deforest-globe',
#                               'esm-ssp585-ssp126Lu', 'land-cCO2', 'hist-noLu',
#                               'land-crop-noFert', 'ssp370-ssp126Lu',
#                               'ssp126-ssp370Lu', 'land-noLu', 'land-noFire',
#                               'land-hist-altStartYear', 'land-cClim', 'omip1',
#                               'pdSST-piAntSIC', 'pdSST-futAntSIC',
#                               'pdSST-pdSIC', 'pdSST-piArcSIC',
#                               'pdSST-futArcSIC', 'lgm', 'ssp119', 'ssp434',
#                               'ssp460', 'ssp534-over']},
#  'source_id': {'count': 47,
#                'values': ['BCC-ESM1', 'CESM2-WACCM', 'CESM2', 'CNRM-ESM2-1',
#                           'BCC-CSM2-MR', 'UKESM1-0-LL', 'GFDL-ESM4',
#                           'GISS-E2-1-G', 'CanESM5', 'CNRM-CM6-1', 'FGOALS-f3-L',
#                           'FGOALS-g3', 'SAM0-UNICON', 'HadGEM3-GC31-LL',
#                           'HadGEM3-GC31-MM', 'AWI-CM-1-1-MR', 'GFDL-AM4',
#                           'GFDL-CM4', 'GISS-E2-1-H', 'E3SM-1-0', 'CAMS-CSM1-0',
#                           'MCM-UA-1-0', 'EC-Earth3-LR', 'EC-Earth3',
#                           'EC-Earth3-Veg', 'MRI-ESM2-0', 'NESM3', 'MIROC-ES2L',
#                           'MIROC6', 'IPSL-CM6A-LR', 'NorCPM1', 'NorESM2-LM',
#                           'FIO-ESM-2-0', 'CNRM-CM6-1-HR', 'FGOALS-f3-H',
#                           'HadGEM3-GC31-HM', 'HadGEM3-GC31-LM', 'GFDL-CM4C192',
#                           'ECMWF-IFS-LR', 'ECMWF-IFS-HR', 'CMCC-CM2-VHR4',
#                           'CMCC-CM2-HR4', 'NICAM16-7S', 'NICAM16-8S',
#                           'NICAM16-9S', 'IPSL-CM6A-ATM-HR', 'MPI-ESM1-2-HR']},
#  'table_id': {'count': 35,
#               'values': ['day', 'Amon', 'AERmonZ', 'CFmon', 'EdayZ', 'Eday',
#                          'CFday', 'EmonZ', 'AERday', 'Emon', 'fx', 'Lmon',
#                          'AERmon', 'Ofx', 'Omon', 'SImon', 'Oyr', 'AERhr',
#                          'Eyr', 'LImon', 'SIday', '6hrPlev', 'CFsubhr',
#                          '6hrLev', 'Oday', 'ImonGre', 'ImonAnt', 'Efx',
#                          'IfxGre', '3hr', '6hrPlevPt', 'E1hr', 'E3hr', 'Oclim',
#                          'CF3hr']}}

# %% [markdown]
# ### Searching for specific datasets
#
# Find the models with **both** dissolved oxygen and temperature data at monthly or annual frequency for both the `historical` and `ssp585` experiments.

# %%
experiments = ['historical', 'ssp585']


def get_models(table_id, variable_id):
    # all models
    models = set(uni_dict['source_id']['values'])

    for experiment_id in experiments:
        query = dict(experiment_id=experiment_id, variable_id=variable_id, 
                     table_id=table_id, grid_label='gn')  
        cat = col.search(**query)
        models = models.intersection({model for model in cat.df.source_id.unique().tolist()})

    # ensure the CESM2 models are not included (oxygen was erroneously submitted to the archive)
    return models - {'CESM2-WACCM', 'CESM2'}
    


models = {}    

# look for models with O2
# prioritize getting data from annual table, if present
models['Oyr.o2'] = get_models('Oyr', 'o2')
models['Omon.o2'] = get_models('Omon', 'o2') - models['Oyr.o2']
have_oxygen = models['Oyr.o2'].union(models['Omon.o2'])

# find models with temperature that also have O2
models['Omon.theta'] = get_models('Omon', 'thetao').intersection(have_oxygen)

models_all = list(models['Omon.theta'])
models
# Out:
# {'Oyr.o2': {'CanESM5', 'IPSL-CM6A-LR', 'MIROC-ES2L'},
#  'Omon.o2': {'CNRM-ESM2-1', 'UKESM1-0-LL'},
#  'Omon.theta': {'CNRM-ESM2-1', 'CanESM5', 'IPSL-CM6A-LR', 'UKESM1-0-LL'}}

# %%
df = pd.DataFrame()
for key, val in models.items():
    model_list = list(val)
    table_id = key.split('.')[0]
    variable_id = key.split('.')[1]
    
    cat = col.search(experiment_id=experiments, table_id=table_id, 
                     variable_id=variable_id, 
                     source_id=model_list, grid_label='gn')
    df = pd.concat((df, cat.df))
    
cat.df = df.copy()
cat.df
# Out:
#         activity_id institution_id    source_id experiment_id  member_id  \
# 294365         CMIP          CCCma      CanESM5    historical   r2i1p1f1
# 294904         CMIP          CCCma      CanESM5    historical   r5i1p1f1
# 295448         CMIP          CCCma      CanESM5    historical  r12i1p1f1
# 296002         CMIP          CCCma      CanESM5    historical   r1i1p2f1
# 297201         CMIP          CCCma      CanESM5    historical  r14i1p1f1
# ...             ...            ...          ...           ...        ...
# 637872  ScenarioMIP           MOHC  UKESM1-0-LL        ssp585   r1i1p1f2
# 637873  ScenarioMIP           MOHC  UKESM1-0-LL        ssp585   r1i1p1f2
# 637966  ScenarioMIP           MOHC  UKESM1-0-LL        ssp585   r2i1p1f2
# 637967  ScenarioMIP           MOHC  UKESM1-0-LL        ssp585   r2i1p1f2
# 637968  ScenarioMIP           MOHC  UKESM1-0-LL        ssp585   r2i1p1f2
#
#        table_id variable_id grid_label  dcpp_init_year    version  \
# 294365      Oyr          o2         gn             NaN  v20190429
# 294904      Oyr          o2         gn             NaN  v20190429
# 295448      Oyr          o2         gn             NaN  v20190429
# 296002      Oyr          o2         gn             NaN  v20190429
# 297201      Oyr          o2         gn             NaN  v20190429
# ...         ...         ...        ...             ...        ...
# 637872     Omon          o2         gn             NaN  v20190726
# 637873     Omon          o2         gn             NaN  v20190726
# 637966     Omon          o2         gn             NaN  v20190726
# 637967     Omon          o2         gn             NaN  v20190726
# 637968     Omon          o2         gn             NaN  v20190726
#
#            time_range                                               path
# 294365      1850-2014  /glade/collections/cmip/CMIP6/CMIP/CCCma/CanES...
# 294904      1850-2014  /glade/collections/cmip/CMIP6/CMIP/CCCma/CanES...
# 295448      1850-2014  /glade/collections/cmip/CMIP6/CMIP/CCCma/CanES...
# 296002      1850-2014  /glade/collections/cmip/CMIP6/CMIP/CCCma/CanES...
# 297201      1850-2014  /glade/collections/cmip/CMIP6/CMIP/CCCma/CanES...
# ...               ...                                                ...
# 637872  205001-209912  /glade/collections/cmip/CMIP6/ScenarioMIP/MOHC...
# 637873  210001-210012  /glade/collections/cmip/CMIP6/ScenarioMIP/MOHC...
# 637966  201501-204912  /glade/collections/cmip/CMIP6/ScenarioMIP/MOHC...
# 637967  210001-210012  /glade/collections/cmip/CMIP6/ScenarioMIP/MOHC...
# 637968  205001-209912  /glade/collections/cmip/CMIP6/ScenarioMIP/MOHC...
#
# [119 rows x 12 columns]

# %% [markdown]
# ### Loading data
#
# The best part about `intake-esm` is that it enables loading data directly into an [xarray.Dataset](http://xarray.pydata.org/en/stable/api.html#dataset).
#
# Note that data on the cloud are in
# [zarr](https://zarr.readthedocs.io/en/stable/) and data on
# [glade](https://www2.cisl.ucar.edu/resources/storage-and-file-systems/glade-file-spaces) are stored as
# [netCDF](https://www.unidata.ucar.edu/software/netcdf/) files. This is opaque to the user!
#
# `intake-esm` has rules for aggegating datasets; these rules are defined in the collection-specification file.

# %%
dset_dict = cat.to_dataset_dict(zarr_kwargs={'consolidated': True, 'decode_times': False}, 
                                cdf_kwargs={'chunks': {'time': 48}, 'decode_times': False})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#
# --> There will be 10 group(s)

# %% [markdown]
# `dset_dict` is a dictionary of `xarray.Dataset`'s; its keys are constructed to refer to compatible groups.

# %%
dset_dict.keys()
# Out:
# dict_keys(['CMIP.CCCma.CanESM5.historical.Oyr.gn', 'CMIP.CNRM-CERFACS.CNRM-ESM2-1.historical.Omon.gn', 'CMIP.IPSL.IPSL-CM6A-LR.historical.Oyr.gn', 'CMIP.MIROC.MIROC-ES2L.historical.Oyr.gn', 'CMIP.MOHC.UKESM1-0-LL.historical.Omon.gn', 'ScenarioMIP.CCCma.CanESM5.ssp585.Oyr.gn', 'ScenarioMIP.CNRM-CERFACS.CNRM-ESM2-1.ssp585.Omon.gn', 'ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp585.Oyr.gn', 'ScenarioMIP.MIROC.MIROC-ES2L.ssp585.Oyr.gn', 'ScenarioMIP.MOHC.UKESM1-0-LL.ssp585.Omon.gn'])

# %% [markdown]
# Get the grid information.

# %%
cat_fx = col.search(source_id=models_all, table_id='Ofx', grid_label='gn')
cat_fx.df
# Out:
#         activity_id institution_id     source_id experiment_id member_id  \
# 11438         C4MIP   CNRM-CERFACS   CNRM-ESM2-1   1pctCO2-bgc  r3i1p1f2
# 11439         C4MIP   CNRM-CERFACS   CNRM-ESM2-1   1pctCO2-bgc  r4i1p1f2
# 11440         C4MIP   CNRM-CERFACS   CNRM-ESM2-1   1pctCO2-bgc  r1i1p1f2
# 11441         C4MIP   CNRM-CERFACS   CNRM-ESM2-1   1pctCO2-bgc  r2i1p1f2
# 11442         C4MIP   CNRM-CERFACS   CNRM-ESM2-1      hist-bgc  r1i1p1f2
# ...             ...            ...           ...           ...       ...
# 698641  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp126  r1i1p1f1
# 698642  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp126  r1i1p1f1
# 698681  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp126  r3i1p1f1
# 698682  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp126  r3i1p1f1
# 698683  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp126  r3i1p1f1
#
#        table_id variable_id grid_label  dcpp_init_year    version time_range  \
# 11438       Ofx   areacello         gn             NaN  v20190711        NaN
# 11439       Ofx   areacello         gn             NaN  v20190711        NaN
# 11440       Ofx   areacello         gn             NaN  v20181109        NaN
# 11441       Ofx   areacello         gn             NaN  v20190711        NaN
# 11442       Ofx   areacello         gn             NaN  v20190711        NaN
# ...         ...         ...        ...             ...        ...        ...
# 698641      Ofx      hfgeou         gn             NaN  v20190121        NaN
# 698642      Ofx       basin         gn             NaN  v20190121        NaN
# 698681      Ofx   areacello         gn             NaN  v20190410        NaN
# 698682      Ofx      hfgeou         gn             NaN  v20190410        NaN
# 698683      Ofx       basin         gn             NaN  v20190410        NaN
#
#                                                      path
# 11438   /glade/collections/cmip/CMIP6/C4MIP/CNRM-CERFA...
# 11439   /glade/collections/cmip/CMIP6/C4MIP/CNRM-CERFA...
# 11440   /glade/collections/cmip/CMIP6/C4MIP/CNRM-CERFA...
# 11441   /glade/collections/cmip/CMIP6/C4MIP/CNRM-CERFA...
# 11442   /glade/collections/cmip/CMIP6/C4MIP/CNRM-CERFA...
# ...                                                   ...
# 698641  /glade/collections/cmip/CMIP6/ScenarioMIP/IPSL...
# 698642  /glade/collections/cmip/CMIP6/ScenarioMIP/IPSL...
# 698681  /glade/collections/cmip/CMIP6/ScenarioMIP/IPSL...
# 698682  /glade/collections/cmip/CMIP6/ScenarioMIP/IPSL...
# 698683  /glade/collections/cmip/CMIP6/ScenarioMIP/IPSL...
#
# [3835 rows x 12 columns]

# %% [markdown]
# We want to prune this query to remove the ensemble dimension.

# %%
# specify a list of queries to eliminate
corrupt_data = [dict(variable_id='areacello', source_id='IPSL-CM6A-LR',
                     experiment_id='historical', member_id='r2i1p1f1')
               ]

# copy the dataframe 
df = cat_fx.df.copy()

# eliminate data
for elim in corrupt_data:
    condition = np.ones(len(df), dtype=bool)
    for key, val in elim.items():
        condition = condition & (df[key] == val)
    df = df.loc[~condition]

df.drop_duplicates(subset=['source_id', 'variable_id'], inplace=True)
df['member_id'] = np.nan
cat_fx.df = df
df
# Out:
#        activity_id institution_id     source_id experiment_id  member_id  \
# 22443         CMIP   CNRM-CERFACS   CNRM-ESM2-1  abrupt-4xCO2        NaN
# 23666         CMIP   CNRM-CERFACS   CNRM-ESM2-1    historical        NaN
# 24506         CMIP   CNRM-CERFACS   CNRM-ESM2-1    historical        NaN
# 24507         CMIP   CNRM-CERFACS   CNRM-ESM2-1    historical        NaN
# 24508         CMIP   CNRM-CERFACS   CNRM-ESM2-1    historical        NaN
# 202044        CMIP           MOHC   UKESM1-0-LL     piControl        NaN
# 202045        CMIP           MOHC   UKESM1-0-LL     piControl        NaN
# 202046        CMIP           MOHC   UKESM1-0-LL     piControl        NaN
# 202047        CMIP           MOHC   UKESM1-0-LL     piControl        NaN
# 293683        CMIP          CCCma       CanESM5  abrupt-4xCO2        NaN
# 294146        CMIP          CCCma       CanESM5    historical        NaN
# 294147        CMIP          CCCma       CanESM5    historical        NaN
# 295762        CMIP          CCCma       CanESM5    historical        NaN
# 529447        CMIP           IPSL  IPSL-CM6A-LR  abrupt-4xCO2        NaN
# 533514        CMIP           IPSL  IPSL-CM6A-LR    historical        NaN
# 535897        CMIP           IPSL  IPSL-CM6A-LR    historical        NaN
# 550621        CMIP           IPSL  IPSL-CM6A-LR     piControl        NaN
# 550623        CMIP           IPSL  IPSL-CM6A-LR     piControl        NaN
#
#        table_id variable_id grid_label  dcpp_init_year    version time_range  \
# 22443       Ofx   areacello         gn             NaN  v20181026        NaN
# 23666       Ofx      deptho         gn             NaN  v20190125        NaN
# 24506       Ofx   masscello         gn             NaN  v20190125        NaN
# 24507       Ofx      hfgeou         gn             NaN  v20190125        NaN
# 24508       Ofx       basin         gn             NaN  v20190125        NaN
# 202044      Ofx       sftof         gn             NaN  v20190705        NaN
# 202045      Ofx      hfgeou         gn             NaN  v20190705        NaN
# 202046      Ofx       basin         gn             NaN  v20190705        NaN
# 202047      Ofx      deptho         gn             NaN  v20190705        NaN
# 293683      Ofx   areacello         gn             NaN  v20190429        NaN
# 294146      Ofx    thkcello         gn             NaN  v20190429        NaN
# 294147      Ofx      deptho         gn             NaN  v20190429        NaN
# 295762      Ofx       sftof         gn             NaN  v20190429        NaN
# 529447      Ofx   areacello         gn             NaN  v20180914        NaN
# 533514      Ofx      hfgeou         gn             NaN  v20180803        NaN
# 535897      Ofx       basin         gn             NaN  v20180803        NaN
# 550621      Ofx       sftof         gn             NaN  v20180802        NaN
# 550623      Ofx   masscello         gn             NaN  v20180802        NaN
#
#                                                      path
# 22443   /glade/collections/cmip/CMIP6/CMIP/CNRM-CERFAC...
# 23666   /glade/collections/cmip/CMIP6/CMIP/CNRM-CERFAC...
# 24506   /glade/collections/cmip/CMIP6/CMIP/CNRM-CERFAC...
# 24507   /glade/collections/cmip/CMIP6/CMIP/CNRM-CERFAC...
# 24508   /glade/collections/cmip/CMIP6/CMIP/CNRM-CERFAC...
# 202044  /glade/collections/cmip/CMIP6/CMIP/MOHC/UKESM1...
# 202045  /glade/collections/cmip/CMIP6/CMIP/MOHC/UKESM1...
# 202046  /glade/collections/cmip/CMIP6/CMIP/MOHC/UKESM1...
# 202047  /glade/collections/cmip/CMIP6/CMIP/MOHC/UKESM1...
# 293683  /glade/collections/cmip/CMIP6/CMIP/CCCma/CanES...
# 294146  /glade/collections/cmip/CMIP6/CMIP/CCCma/CanES...
# 294147  /glade/collections/cmip/CMIP6/CMIP/CCCma/CanES...
# 295762  /glade/collections/cmip/CMIP6/CMIP/CCCma/CanES...
# 529447  /glade/collections/cmip/CMIP6/CMIP/IPSL/IPSL-C...
# 533514  /glade/collections/cmip/CMIP6/CMIP/IPSL/IPSL-C...
# 535897  /glade/collections/cmip/CMIP6/CMIP/IPSL/IPSL-C...
# 550621  /glade/collections/cmip/CMIP6/CMIP/IPSL/IPSL-C...
# 550623  /glade/collections/cmip/CMIP6/CMIP/IPSL/IPSL-C...

# %%
fx_dsets = cat_fx.to_dataset_dict(zarr_kwargs={'consolidated': True, 'decode_times': False}, 
                                  cdf_kwargs={'chunks': {}, 'decode_times': False})
# Out:
# xarray will load netCDF datasets with dask using a single chunk for all arrays.
#                      For effective chunking, please provide chunks in cdf_kwargs.
#                      For example: cdf_kwargs={'chunks': {'time': 36}}
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#
# --> There will be 8 group(s)

# %%
fx_dsets.keys()
# Out:
# dict_keys(['CMIP.CCCma.CanESM5.abrupt-4xCO2.Ofx.gn', 'CMIP.CCCma.CanESM5.historical.Ofx.gn', 'CMIP.CNRM-CERFACS.CNRM-ESM2-1.abrupt-4xCO2.Ofx.gn', 'CMIP.CNRM-CERFACS.CNRM-ESM2-1.historical.Ofx.gn', 'CMIP.IPSL.IPSL-CM6A-LR.abrupt-4xCO2.Ofx.gn', 'CMIP.IPSL.IPSL-CM6A-LR.historical.Ofx.gn', 'CMIP.IPSL.IPSL-CM6A-LR.piControl.Ofx.gn', 'CMIP.MOHC.UKESM1-0-LL.piControl.Ofx.gn'])

# %%
for key, ds in fx_dsets.items():
    print(key)
    print(ds.data_vars)
    print()
# Out:
# CMIP.CCCma.CanESM5.abrupt-4xCO2.Ofx.gn
# Data variables:
#     latitude            (j, i) float64 dask.array<chunksize=(291, 360), meta=np.ndarray>
#     longitude           (j, i) float64 dask.array<chunksize=(291, 360), meta=np.ndarray>
#     vertices_latitude   (j, i, vertices) float64 dask.array<chunksize=(291, 360, 4), meta=np.ndarray>
#     vertices_longitude  (j, i, vertices) float64 dask.array<chunksize=(291, 360, 4), meta=np.ndarray>
#     areacello           (j, i) float32 dask.array<chunksize=(291, 360), meta=np.ndarray>
#
# CMIP.CCCma.CanESM5.historical.Ofx.gn
# Data variables:
#     lev_bnds            (lev, bnds) float64 dask.array<chunksize=(45, 2), meta=np.ndarray>
#     latitude            (j, i) float64 dask.array<chunksize=(291, 360), meta=np.ndarray>
#     longitude           (j, i) float64 dask.array<chunksize=(291, 360), meta=np.ndarray>
#     vertices_latitude   (j, i, vertices) float64 dask.array<chunksize=(291, 360, 4), meta=np.ndarray>
#     vertices_longitude  (j, i, vertices) float64 dask.array<chunksize=(291, 360, 4), meta=np.ndarray>
#     thkcello            (lev, j, i) float32 dask.array<chunksize=(45, 291, 360), meta=np.ndarray>
#     deptho              (j, i) float32 dask.array<chunksize=(291, 360), meta=np.ndarray>
#     type                |S3 ...
#     sftof               (j, i) float32 dask.array<chunksize=(291, 360), meta=np.ndarray>
#
# CMIP.CNRM-CERFACS.CNRM-ESM2-1.abrupt-4xCO2.Ofx.gn
# Data variables:
#     lat         (y, x) float64 dask.array<chunksize=(294, 362), meta=np.ndarray>
#     lon         (y, x) float64 dask.array<chunksize=(294, 362), meta=np.ndarray>
#     bounds_lon  (y, x, nvertex) float64 dask.array<chunksize=(294, 362, 4), meta=np.ndarray>
#     bounds_lat  (y, x, nvertex) float64 dask.array<chunksize=(294, 362, 4), meta=np.ndarray>
#     areacello   (y, x) float32 dask.array<chunksize=(294, 362), meta=np.ndarray>
#
# CMIP.CNRM-CERFACS.CNRM-ESM2-1.historical.Ofx.gn
# Data variables:
#     lat         (y, x) float64 dask.array<chunksize=(294, 362), meta=np.ndarray>
#     lon         (y, x) float64 dask.array<chunksize=(294, 362), meta=np.ndarray>
#     bounds_lon  (y, x, nvertex) float64 dask.array<chunksize=(294, 362, 4), meta=np.ndarray>
#     bounds_lat  (y, x, nvertex) float64 dask.array<chunksize=(294, 362, 4), meta=np.ndarray>
#     lev_bounds  (lev, axis_nbounds) float64 dask.array<chunksize=(75, 2), meta=np.ndarray>
#     deptho      (lev, y, x) float32 dask.array<chunksize=(75, 294, 362), meta=np.ndarray>
#     masscello   (lev, y, x) float32 dask.array<chunksize=(75, 294, 362), meta=np.ndarray>
#     hfgeou      (y, x) float32 dask.array<chunksize=(294, 362), meta=np.ndarray>
#     basin       (y, x) float32 dask.array<chunksize=(294, 362), meta=np.ndarray>
#
# CMIP.IPSL.IPSL-CM6A-LR.abrupt-4xCO2.Ofx.gn
# Data variables:
#     nav_lat         (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     nav_lon         (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     bounds_nav_lon  (y, x, nvertex) float32 dask.array<chunksize=(332, 362, 4), meta=np.ndarray>
#     bounds_nav_lat  (y, x, nvertex) float32 dask.array<chunksize=(332, 362, 4), meta=np.ndarray>
#     area            (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     areacello       (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#
# CMIP.IPSL.IPSL-CM6A-LR.historical.Ofx.gn
# Data variables:
#     nav_lat         (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     nav_lon         (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     bounds_nav_lon  (y, x, nvertex) float32 dask.array<chunksize=(332, 362, 4), meta=np.ndarray>
#     bounds_nav_lat  (y, x, nvertex) float32 dask.array<chunksize=(332, 362, 4), meta=np.ndarray>
#     area            (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     hfgeou          (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     basin           (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#
# CMIP.IPSL.IPSL-CM6A-LR.piControl.Ofx.gn
# Data variables:
#     nav_lat         (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     nav_lon         (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     bounds_nav_lon  (y, x, nvertex) float32 dask.array<chunksize=(332, 362, 4), meta=np.ndarray>
#     bounds_nav_lat  (y, x, nvertex) float32 dask.array<chunksize=(332, 362, 4), meta=np.ndarray>
#     area            (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     type            |S255 ...
#     sftof           (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     deptht_bounds   (deptht, axis_nbounds) float32 dask.array<chunksize=(75, 2), meta=np.ndarray>
#     masscello       (deptht, y, x) float32 dask.array<chunksize=(75, 332, 362), meta=np.ndarray>
#
# CMIP.MOHC.UKESM1-0-LL.piControl.Ofx.gn
# Data variables:
#     latitude            (j, i) float32 dask.array<chunksize=(330, 360), meta=np.ndarray>
#     longitude           (j, i) float32 dask.array<chunksize=(330, 360), meta=np.ndarray>
#     vertices_latitude   (j, i, vertices) float32 dask.array<chunksize=(330, 360, 4), meta=np.ndarray>
#     vertices_longitude  (j, i, vertices) float32 dask.array<chunksize=(330, 360, 4), meta=np.ndarray>
#     type                |S3 ...
#     sftof               (j, i) float32 dask.array<chunksize=(330, 360), meta=np.ndarray>
#     hfgeou              (j, i) float32 dask.array<chunksize=(330, 360), meta=np.ndarray>
#     basin               (j, i) float64 dask.array<chunksize=(330, 360), meta=np.ndarray>
#     deptho              (j, i) float32 dask.array<chunksize=(330, 360), meta=np.ndarray>
